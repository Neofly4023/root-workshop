// %% [markdown]
// **Preparation of the histogram to fit
//
// Create First an empty histogram with 50 bins with range [-10,10]

// %%
TH1D h1("h1", "h1", 50, -10, 10);

// %% [markdown]
// Fill the histogram with 10000 Gaussian Random number with mean=1 and sigma=2
// Hint: Find the TRandom3 documentation.
// Hint 2: If you don't find what you are looking for, check also the TRandom functions on TRandom3's documentation

// %%
TRandom3 randomGenerator(1);
  for (int i = 0; i < 1000; ++i) {
    h1.Fill(randomGenerator.Gaus(1, 2));
  }

// %% [markdown]
// Let's now draw the histogram

// %%
TCanvas C = new TCanvas("Canv","The Title",800,800);

// %%
h1.Draw();
C.Draw();
